# %% [markdown]
# #Assignment 1
# The use of AI is not completely prohibited, but it should be used wisely. Avoid directly copying and pasting answers. You may use AI for understanding syntax, functionality, and concepts, but make an effort to debug and solve problems on your own.
#
# In the end, it is your learning and understanding that will benefit the most.

# %% [markdown]
# ### Python and NumPy Assignment: Data Analysis Fundamentals
#
# This assignment is divided into two parts. Part 1 focuses on Python fundamentals, while Part 2 introduces basic NumPy operations. Part 3 is bonus problem this is highly recommended to be done as we will be using these concept very often.

# %% [markdown]
# ### Part 1: Python List Operations
#
# **Objective**: Practice writing a Python function to process a list of numbers.
#
# **Scenario**: You have a list of daily temperature readings (in Celsius) for a week. You need to identify days where the temperature was above a certain threshold and calculate their average.
#
# **Instructions**:
# 1.  **Run the pre-code block below** to define the `daily_temperatures` list and `temperature_threshold`.
# 2.  **Create a Python function** named `analyze_temperatures` that takes two arguments: a list of temperatures and a threshold temperature.
# 3.  **Inside the function**:
#     *   Identify all temperatures that are *strictly greater* than the given threshold.
#     *   If there are any temperatures above the threshold, calculate their average.
#     *   Return the list of above-threshold temperatures and their average. If no temperatures are above the threshold, return an empty list and `None` for the average.
# 4.  **Call your function** with the provided `daily_temperatures` and `temperature_threshold`.
# 5.  **Print** the results in a user-friendly format.

# %%
# Pre-code for Part 1
daily_temperatures = [22, 25, 19, 28, 23, 30, 26] # Temperatures in Celsius
temperature_threshold = 24

# %%
# Pre-code for Part 1
daily_temperatures = [22, 25, 19, 28, 23, 30, 26] # Temperatures in Celsius
temperature_threshold = 24

# Your code for Part 1 goes here

def analyze_temperatures(temperatures, threshold):
    # TODO: Implement the function as per instructions
    above_threshold = []
    for x in daily_temperatures:
        if x > threshold:
           above_threshold.append(x)            
    if (len(above_threshold)>0):
        avg_temp = (sum(above_threshold))/len(above_threshold)
    else:
        avg_temp = None

    return above_threshold, avg_temp
# TODO: Call the function and print results

temps, avgTemp = analyze_temperatures(daily_temperatures, temperature_threshold)

print (temps)
print (avgTemp)
# Out:
# [25, 28, 30, 26]
# 27.25

# %% [markdown]
# #### Part 1 (Continued): Random List Generation and Analysis
#
# **Objective**: Generate multiple lists of random integers and perform basic statistical operations.
#
# **Instructions**:
# 1.  **Generate 10 separate lists**, where each list contains 5 random integers between 1 and 100 (inclusive).
# 2.  For each of these 10 lists:
#     *   Calculate the **sum** of its elements.
#     *   Calculate the **average** of its elements.
# 3.  Identify and print the list that has the **highest sum** among all 10 generated lists, along with its sum and average.

# %%
import random

# Your code for Part 1 (Continued) goes here

# TODO: Generate 10 lists of random integers
ListOfLists = []

for i in range (10):
    random_list = []
    for j in range (5):
        random_list.append(random.randint(1, 100))
    ListOfLists.append(random_list)


# TODO: Calculate sum and average for each list

def analyze_lists(lists):
    HighestSum = 0
    High_list=[]
    curr_sum=0

    for x in lists:
        curr_sum = sum (x)
        if (curr_sum>HighestSum):
            HighestSum = curr_sum
            High_list = x
    return High_list

# TODO: Find and print the list with the highest sum

HighestSumList = analyze_lists(ListOfLists)
print("List with highest sum :")
print(HighestSumList)
print("Highest sum = ", sum(HighestSumList))
print("Highest Average = ", sum(HighestSumList)/len(HighestSumList))
# Out:
# List with highest sum :
# [70, 96, 39, 39, 53]
# Highest sum =  297
# Highest Average =  59.4

# %% [markdown]
# ### Part 2: Introduction to NumPy
#
# **Objective**: Get hands-on with NumPy for numerical operations, including installation.
#
# **Scenario**: You want to perform faster and more efficient numerical operations on the temperature data using NumPy.
#
# **Instructions**:
# 1.  **Install NumPy**: Run the `pip install numpy` command in the cell below.
# 2.  **Import NumPy** into your Python environment.
# 3.  **Convert** the `daily_temperatures` list from Part 1 into a NumPy array.
# 4.  **Using NumPy functions**:
#     *   Find the **maximum** temperature in the array.
#     *   Calculate the **standard deviation** of the temperatures.
#     *   Create a new NumPy array containing only temperatures that are **greater than or equal to 25** .
# 5.  **Print** the results clearly, indicating which value corresponds to which calculation.

# %%
# Step 1: Install NumPy (run this cell)
# !pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.5 MB ? eta -:--:--
#    ----- ---------------------------------- 1.8/12.5 MB 11.5 MB/s eta 0:00:01
#    --------------- ------------------------ 4.7/12.5 MB 12.1 MB/s eta 0:00:01
#    -------------------------- ------------- 8.4/12.5 MB 14.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.0/12.5 MB 13.9 MB/s eta 0:00:01
#    ---------------------------------------- 12.5/12.5 MB 12.2 MB/s  0:00:01
# ...
# [notice] A new release of pip is available: 25.2 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Your code for Part 2 goes here

# TODO: Import NumPy
import numpy as np

# TODO: Convert daily_temperatures to a NumPy array

daily_temperatures = [22, 25, 19, 28, 23, 30, 26] # Temperatures in Celsius
temp_array = np.array(daily_temperatures)

# TODO: Perform NumPy operations and print results

max_temp = np.max(temp_array)  # Max temperature
std_temp = np.std(temp_array)  # Standard Deviation
filtered_temp = temp_array[temp_array>=25] # Temperature greater than or equal to 25

print("Temperature Array: ", temp_array)
print("Maximum Temperature: ", max_temp)
print("Standard Deviation: ", std_temp)
print("Temperature greater than or equal to 25 : ", filtered_temp)
# Out:
# Temperature Array:  [22 25 19 28 23 30 26]
# Maximum Temperature:  30
# Standard Deviation:  3.4522988495984492
# Temperature greater than or equal to 25 :  [25 28 30 26]

# %% [markdown]
# ### Part 3: Bonus Problem - Object-Oriented Book Management
#
# **Objective**: Practice object-oriented programming concepts (`class`, `__init__`) by creating a `Book` class and performing operations on a collection of books.
#
# **Scenario**: You are managing a small library and want to organize book information using Python classes.
#
# **Instructions**:
# 1.  **Define a `Book` class** with an `__init__` method that takes `title` and `author` as arguments and stores them as instance attributes.
# 2.  **Create a list of `Book` objects** using the provided `book_data`.
# 3.  **Implement a method** within the `Book` class (or a separate function) to:
#     *   Find the book with the **longest title**.
#     *   List all books written by a specific author (e.g., 'George Orwell').
# 4.  **Print** the results in a clear and readable format.

# %%
# Pre-code for Part 3
book_data = [
    {'title': '1984', 'author': 'George Orwell'},
    {'title': 'Brave New World', 'author': 'Aldous Huxley'},
    {'title': 'Animal Farm', 'author': 'George Orwell'},
    {'title': 'The Great Gatsby', 'author': 'F. Scott Fitzgerald'},
    {'title': 'To Kill a Mockingbird', 'author': 'Harper Lee'}
]

# Your code for Part 3 goes here

# TODO: Define the Book class
class Book:
    def __init__(self, title, author):
        self.title = title
        self.author = author
# TODO: Create Book objects and perform operations
books=[]

for items in book_data:
    book = Book(items['title'], items['author'])
    books.append(book)

longest_book=books[0]

for book in books:
  if len(book.title)>len(longest_book.title):
       longest_book = book

George_books=[]

for book in books:
    if book.author == "George Orwell":
        George_books.append(book)

# TODO: Print results

print("Book with longest title: ")
print(longest_book.title, "-", longest_book.author)
print("\nBooks by George Orwell:")
for book in George_books:
    print(book.title)
# Out:
# Book with longest title:
# To Kill a Mockingbird - Harper Lee
#
# Books by George Orwell:
# 1984
# Animal Farm
